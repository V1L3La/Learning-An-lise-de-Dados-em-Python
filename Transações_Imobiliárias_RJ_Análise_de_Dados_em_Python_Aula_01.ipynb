# %% [markdown]
# <a href="https://colab.research.google.com/github/V1L3La/Learning-An-lise-de-Dados-em-Python/blob/main/Transa%C3%A7%C3%B5es_Imobili%C3%A1rias_RJ_An%C3%A1lise_de_Dados_em_Python_Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Dados  prefeitura rio
# https://www.rio.rj.gov.br/web/transparencia/dados-abertos#:~:text=Dados%20s%C3%A3o%20abertos%20quando%20qualquer,defini%C3%A7%C3%A3o%20da%20Open%20Knowledge%20International.
#
# #### Análise de Dados com Python usando Pandas  (resumo)
# https://minerandodados.com.br/analise-de-dados-com-python-usando-pandas/
#
#
# #### Análise de Dados em Python: Aula 01
# https://youtu.be/W_Bz7M91R1Q
#
# #### Export to Github
# https://colab.research.google.com/notebooks/

# %%
import pandas as pd
# . é igual a "acessar funções da biblioteca...." 
df = pd.read_csv('https://raw.githubusercontent.com/V1L3La/Learning-An-lise-de-Dados-em-Python/main/Transa%25C3%25A7%25C3%25B5es_Imobili%25C3%25A1rias_-_ITBI.csv')  
df
# Out:
#                X          Y   OBJECTID  ...    TIPOLOGIA  TOTAL VALOR_RECOLHIDO
# 0     -43.184292 -22.897272          1  ...     ESPECIAL      3       411051.79
# 1     -43.272085 -22.879776          2  ...         SALA     63       348093.30
# 2     -43.488262 -22.840977          3  ...         CASA     19        72341.57
# 3     -43.157847 -22.948312          4  ...  APARTAMENTO      3        45164.61
# 4     -43.393991 -22.895853          5  ...  APARTAMENTO     12        58594.20
# ...          ...        ...        ...  ...          ...    ...             ...
# 57523 -43.512624 -22.924892  117519196  ...      TERRENO     22       389331.75
# 57524 -43.637729 -22.998166  117519197  ...      TERRENO      1          469.03
# 57525 -43.367763 -22.993739  117519198  ...      TERRENO     14       868750.83
# 57526 -43.589322 -22.992150  117519199  ...      TERRENO     29       177988.67
# 57527 -43.186647 -22.797700  117519201  ...         CASA      1        13500.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57528 entries, 0 to 57527
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   X                57528 non-null  float64
#  1   Y                57528 non-null  float64
#  2   OBJECTID         57528 non-null  int64
#  3   ANO              57528 non-null  int64
#  4   MES              57528 non-null  int64
#  5   NOME             57528 non-null  object
#  6   UTILIZACAO       57528 non-null  object
#  7   TIPOLOGIA        57528 non-null  object
#  8   TOTAL            57528 non-null  int64
#  9   VALOR_RECOLHIDO  57528 non-null  float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 4.4+ MB

# %%
df.rename(columns={'NOME': 'NOME_DO_BAIRRO'}, inplace = True)   # troca o nome de uma coluna
df
# Out:
#                X          Y   OBJECTID  ...    TIPOLOGIA  TOTAL VALOR_RECOLHIDO
# 0     -43.184292 -22.897272          1  ...     ESPECIAL      3       411051.79
# 1     -43.272085 -22.879776          2  ...         SALA     63       348093.30
# 2     -43.488262 -22.840977          3  ...         CASA     19        72341.57
# 3     -43.157847 -22.948312          4  ...  APARTAMENTO      3        45164.61
# 4     -43.393991 -22.895853          5  ...  APARTAMENTO     12        58594.20
# ...          ...        ...        ...  ...          ...    ...             ...
# 57523 -43.512624 -22.924892  117519196  ...      TERRENO     22       389331.75
# 57524 -43.637729 -22.998166  117519197  ...      TERRENO      1          469.03
# 57525 -43.367763 -22.993739  117519198  ...      TERRENO     14       868750.83
# 57526 -43.589322 -22.992150  117519199  ...      TERRENO     29       177988.67
# 57527 -43.186647 -22.797700  117519201  ...         CASA      1        13500.00
#
# ...

# %%
df.groupby("NOME_DO_BAIRRO").max()
# Out:
#                            X          Y  ...  TOTAL  VALOR_RECOLHIDO
# NOME_DO_BAIRRO                           ...
# ABOLICAO          -43.299412 -22.885970  ...     13        101810.60
# ACARI             -43.341001 -22.822161  ...      2         66558.13
# AGUA SANTA        -43.311638 -22.911132  ...     32        301111.50
# ALTO DA BOA VISTA -43.260613 -22.960629  ...      5        636978.45
# ANCHIETA          -43.398776 -22.822954  ...     11         90000.00
# ...                      ...        ...  ...    ...              ...
# VILA KOSMOS       -43.303456 -22.854020  ...     11        221744.61
# VILA MILITAR      -43.403273 -22.861487  ...      3         88430.87
# VILA VALQUEIRE    -43.367044 -22.887927  ...     86        505519.35
# VISTA ALEGRE      -43.314999 -22.830153  ...     10         72759.60
# ZUMBI             -43.176014 -22.821116  ...      7         64848.31
#
# [158 rows x 9 columns]

# %%
df['NOME_DO_BAIRRO'].unique()    # valores unicos(sem repetir) na coluna especificada
# Out:
# array(['SAUDE', 'DEL CASTILHO', 'BANGU', 'URCA', 'JARDIM SULACAP',
#        'JARDIM GUANABARA', 'PRAIA DA BANDEIRA', 'COSMOS', 'GUADALUPE',
#        'GRAJAU', 'OLARIA', 'VAZ LOBO', 'CAMPO GRANDE', 'AGUA SANTA',
#        'VILA DA PENHA', 'REALENGO', 'OSWALDO CRUZ', 'BENFICA',
#        'MARIA DA GRACA', 'SAO CRISTOVAO', 'CACHAMBI', 'PORTUGUESA',
#        'COPACABANA', 'PAVUNA', 'BARRA DA TIJUCA', 'PITANGUEIRAS',
#        'TIJUCA', 'PECHINCHA', 'MANGUEIRA', 'BONSUCESSO', 'BOTAFOGO',
#        'SANTA CRUZ', 'ABOLICAO', 'ROCHA', 'VISTA ALEGRE', 'SANTISSIMO',
#        'PAQUETA', 'TAUA', 'JOA', 'ENGENHO DE DENTRO', 'LARANJEIRAS',
#        'PENHA', 'CATETE', 'VARGEM PEQUENA', 'ALTO DA BOA VISTA', 'LAGOA',
#        'PRACA SECA', 'JACARE', 'RECREIO DOS BANDEIRANTES', 'MEIER',
#        'ROCHA MIRANDA', 'PARQUE COLUMBIA', 'SANTO CRISTO', 'COCOTA',
#        'ENGENHO NOVO', 'SANTA TERESA', 'CENTRO', 'BENTO RIBEIRO',
#        'CAVALCANTI', 'JARDIM CARIOCA', 'LINS DE VASCONCELOS',
# ...

# %%
  df['NOME_DO_BAIRRO'].value_counts()              # conta valores totais DENTRO da coluna  e  [] = selecionar
# Out:
# BARRA DA TIJUCA             1659
# COPACABANA                  1213
# CENTRO                      1119
# RECREIO DOS BANDEIRANTES    1062
# CAMPO GRANDE                1018
#                             ...
# ACARI                         29
# DEODORO                       27
# ROCINHA                        6
# CIDADE UNIVERSITARIA           3
# GRUMARI                        2
# Name: NOME_DO_BAIRRO, Length: 158, dtype: int64

# %%
Pesquisa_VIG = df.query('VALOR_RECOLHIDO < 3000.00 & NOME_DO_BAIRRO =="VIGARIO GERAL"')
Pesquisa_VIG
# Out:
#                X          Y  ...  TOTAL  VALOR_RECOLHIDO
# 118   -43.310217 -22.809022  ...      1          1089.70
# 356   -43.310217 -22.809022  ...      1          2760.00
# 534   -43.310217 -22.809022  ...      1           804.60
# 694   -43.310217 -22.809022  ...      1          1487.42
# 1504  -43.310217 -22.809022  ...      1          2500.00
# ...          ...        ...  ...    ...              ...
# 51707 -43.310217 -22.809022  ...      1          1222.88
# 52051 -43.310217 -22.809022  ...      1          2700.00
# 53506 -43.310217 -22.809022  ...      2          2909.70
# 53941 -43.310217 -22.809022  ...      1          2893.63
# 54665 -43.310217 -22.809022  ...      1          1818.64
#
# [153 rows x 10 columns]

# %%
Pesquisa_VIG['VALOR_RECOLHIDO'] = Pesquisa_VIG['VALOR_RECOLHIDO'].astype(float)
Pesquisa_VIG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 118 to 54665
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   X                153 non-null    float64
#  1   Y                153 non-null    float64
#  2   OBJECTID         153 non-null    int64
#  3   ANO              153 non-null    int64
#  4   MES              153 non-null    int64
#  5   NOME_DO_BAIRRO   153 non-null    object
#  6   UTILIZACAO       153 non-null    object
#  7   TIPOLOGIA        153 non-null    object
#  8   TOTAL            153 non-null    int64
#  9   VALOR_RECOLHIDO  153 non-null    float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 13.1+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
Pesquisa_VIG['VALOR_RECOLHIDO'].plot.hist(title='VALOR_RECOLHIDO', bins=30, edgecolor='black')

# %%
df
# Out:
#                X          Y   OBJECTID  ...    TIPOLOGIA  TOTAL VALOR_RECOLHIDO
# 0     -43.184292 -22.897272          1  ...     ESPECIAL      3       411051.79
# 1     -43.272085 -22.879776          2  ...         SALA     63       348093.30
# 2     -43.488262 -22.840977          3  ...         CASA     19        72341.57
# 3     -43.157847 -22.948312          4  ...  APARTAMENTO      3        45164.61
# 4     -43.393991 -22.895853          5  ...  APARTAMENTO     12        58594.20
# ...          ...        ...        ...  ...          ...    ...             ...
# 57523 -43.512624 -22.924892  117519196  ...      TERRENO     22       389331.75
# 57524 -43.637729 -22.998166  117519197  ...      TERRENO      1          469.03
# 57525 -43.367763 -22.993739  117519198  ...      TERRENO     14       868750.83
# 57526 -43.589322 -22.992150  117519199  ...      TERRENO     29       177988.67
# 57527 -43.186647 -22.797700  117519201  ...         CASA      1        13500.00
#
# ...

# %%
df_Vigaris = df[df["NOME_DO_BAIRRO"] == 'VIGARIO GERAL']    # cria um novo dataframe a partir do antigo
df_Vigaris
# Out:
#                X          Y  ...  TOTAL  VALOR_RECOLHIDO
# 117   -43.310217 -22.809022  ...      2         15275.38
# 118   -43.310217 -22.809022  ...      1          1089.70
# 356   -43.310217 -22.809022  ...      1          2760.00
# 534   -43.310217 -22.809022  ...      1           804.60
# 694   -43.310217 -22.809022  ...      1          1487.42
# ...          ...        ...  ...    ...              ...
# 56186 -43.310217 -22.809022  ...      1          6660.00
# 56246 -43.310217 -22.809022  ...      7         27148.66
# 56772 -43.310217 -22.809022  ...      3         12566.02
# 57248 -43.310217 -22.809022  ...      1          5100.00
# 57476 -43.310217 -22.809022  ...      2          6660.00
#
# [384 rows x 10 columns]

# %%
Pesquisa_VIG = df.query('NOME_DO_BAIRRO =="VIGARIO GERAL" & UTILIZACAO =="NAO RESIDENCIAL"')
Pesquisa_VIG
# Out:
#                X          Y  ...  TOTAL  VALOR_RECOLHIDO
# 117   -43.310217 -22.809022  ...      2         15275.38
# 118   -43.310217 -22.809022  ...      1          1089.70
# 1219  -43.310217 -22.809022  ...      3         62207.25
# 1268  -43.310217 -22.809022  ...      3         11644.05
# 1504  -43.310217 -22.809022  ...      1          2500.00
# ...          ...        ...  ...    ...              ...
# 52654 -43.310217 -22.809022  ...      1         12830.49
# 53386 -43.310217 -22.809022  ...      1         11610.00
# 54553 -43.310217 -22.809022  ...      1          3030.96
# 55142 -43.310217 -22.809022  ...      7          9811.71
# 55994 -43.310217 -22.809022  ...      1         16500.00
#
# [155 rows x 10 columns]

# %%
df_Vigaris['TIPOLOGIA'].unique()
# Out:
# array(['INDUSTRIA', 'ARMAZEM/DEPOSITO', 'CASA/APTO (PROLETARIO)',
#        'TERRENO', 'APARTAMENTO', 'LOJA', 'GALPAO', 'CASA', 'ESPECIAL',
#        'SALA', 'TELHEIRO ANEXO'], dtype=object)

# %%
df_Vigaris[df_Vigaris['TIPOLOGIA'].str.contains('LPAO')].count()
# Out:
# X                  55
# Y                  55
# OBJECTID           55
# ANO                55
# MES                55
# NOME_DO_BAIRRO     55
# UTILIZACAO         55
# TIPOLOGIA          55
# TOTAL              55
# VALOR_RECOLHIDO    55
# dtype: int64

# %%
df.sample(10)   #lista linhas aleatórias
# Out:
#                X          Y   OBJECTID  ...    TIPOLOGIA  TOTAL VALOR_RECOLHIDO
# 26850 -43.199020 -22.956363      26851  ...     ESPECIAL      2       880999.20
# 38582 -43.240371 -22.892155      38583  ...         LOJA      5        47190.32
# 51843 -43.268482 -22.909097  107314589  ...  APARTAMENTO     11        60103.43
# 43959 -43.706368 -22.916470      43960  ...  APARTAMENTO      3        13845.77
# 19959 -43.370695 -22.859299      19960  ...         CASA      3        13670.63
# 17920 -43.203122 -22.984105      17921  ...  APART-HOTEL      1        36540.00
# 47691 -43.274162 -22.889853   61372461  ...         CASA      2        40244.27
# 27261 -43.433711 -22.881000      27262  ...  APARTAMENTO      4        23131.57
# 29693 -43.398776 -22.822954      29694  ...         CASA      2         4082.89
# 6235  -43.384536 -22.921757       6236  ...         SALA      4        15870.51
#
# [10 rows x 10 columns]

# %%
df
# Out:
#                X          Y   OBJECTID  ...    TIPOLOGIA  TOTAL VALOR_RECOLHIDO
# 0     -43.184292 -22.897272          1  ...     ESPECIAL      3       411051.79
# 1     -43.272085 -22.879776          2  ...         SALA     63       348093.30
# 2     -43.488262 -22.840977          3  ...         CASA     19        72341.57
# 3     -43.157847 -22.948312          4  ...  APARTAMENTO      3        45164.61
# 4     -43.393991 -22.895853          5  ...  APARTAMENTO     12        58594.20
# ...          ...        ...        ...  ...          ...    ...             ...
# 57523 -43.512624 -22.924892  117519196  ...      TERRENO     22       389331.75
# 57524 -43.637729 -22.998166  117519197  ...      TERRENO      1          469.03
# 57525 -43.367763 -22.993739  117519198  ...      TERRENO     14       868750.83
# 57526 -43.589322 -22.992150  117519199  ...      TERRENO     29       177988.67
# 57527 -43.186647 -22.797700  117519201  ...         CASA      1        13500.00
#
# ...

# %%
# Criar subconjunto ou sub divisão

df_listagem_cordovil = df[df['NOME_DO_BAIRRO'] == 'CORDOVIL']
df_listagem_cordovil.head()
# Out:
#              X          Y  OBJECTID  ...    TIPOLOGIA  TOTAL VALOR_RECOLHIDO
# 184 -43.292698 -22.818933       185  ...         CASA      2         2333.41
# 196 -43.292698 -22.818933       197  ...  APARTAMENTO      4        30330.15
# 232 -43.292698 -22.818933       233  ...     ESPECIAL      1           54.41
# 283 -43.292698 -22.818933       284  ...         CASA      7         2266.03
# 809 -43.292698 -22.818933       810  ...         CASA      3         5877.33
#
# [5 rows x 10 columns]

# %%
df_listagem_cordovil.isna()
# Out:
#            X      Y  OBJECTID  ...  TIPOLOGIA  TOTAL  VALOR_RECOLHIDO
# 184    False  False     False  ...      False  False            False
# 196    False  False     False  ...      False  False            False
# 232    False  False     False  ...      False  False            False
# 283    False  False     False  ...      False  False            False
# 809    False  False     False  ...      False  False            False
# ...      ...    ...       ...  ...        ...    ...              ...
# 56363  False  False     False  ...      False  False            False
# 56472  False  False     False  ...      False  False            False
# 56496  False  False     False  ...      False  False            False
# 56710  False  False     False  ...      False  False            False
# 56714  False  False     False  ...      False  False            False
#
# [371 rows x 10 columns]

# %%
df[df['NOME_DO_BAIRRO'] == 'CORDOVIL']
# Out:
#                X          Y  ...  TOTAL  VALOR_RECOLHIDO
# 184   -43.292698 -22.818933  ...      2          2333.41
# 196   -43.292698 -22.818933  ...      4         30330.15
# 232   -43.292698 -22.818933  ...      1            54.41
# 283   -43.292698 -22.818933  ...      7          2266.03
# 809   -43.292698 -22.818933  ...      3          5877.33
# ...          ...        ...  ...    ...              ...
# 56363 -43.292698 -22.818933  ...      1          7619.13
# 56472 -43.292698 -22.818933  ...      2         12900.00
# 56496 -43.292698 -22.818933  ...      2         15000.00
# 56710 -43.292698 -22.818933  ...      2          7443.65
# 56714 -43.292698 -22.818933  ...      1          9450.00
#
# [371 rows x 10 columns]

# %%
df_listagem_cordovil['TIPOLOGIA'].value_counts()
# Out:
# CASA                      127
# APARTAMENTO               108
# ESPECIAL                   42
# LOJA                       23
# GALPAO                     20
# TERRENO                    17
# CASA/APTO (PROLETARIO)     14
# INDUSTRIA                  11
# SALA                        7
# SOBRELOJA                   1
# CASA (PROLETARIO)           1
# Name: TIPOLOGIA, dtype: int64

# %%
# %matplotlib inline
df_listagem_cordovil['TIPOLOGIA'].value_counts(ascending=True).plot.hist(
    title='TIPOLOGIA', bins=30, edgecolor='yellow')

# %%
df_listagem_cordovil.plot.scatter(x='VALOR_RECOLHIDO', y='TIPOLOGIA')
